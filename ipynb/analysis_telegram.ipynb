# %%
import pandas as pd
import deepl
import numpy as np 
import re
# from transformers import pipeline
import os
# from dotenv import load_dotenv
# load_dotenv() 

# declear API keys
DEEPL_API_KEY = os.getenv("DEEPL_API_KEY")
AIRTABLE_API_KEY = os.getenv("AIRTABLE_API_KEY")
AIRTABLE_BASE_ID_UKR = os.getenv("AIRTABLE_BASE_ID_UKR")





# TODO proper text cleaning 
# TODO cost calculation for whole df 
# TODO does lambda save results if limit hit
# TODO filter for websites, adresses, 
# TODO how can NLP be used within Government Crisis, think of RQ ?

# %%
df = pd.read_csv('../data/telegram/DACH/df_clean.csv')
df.shape
# Out:
# (1608223, 3)

# %%
df.chat.unique()
# Out:
# array(['https://t.me/AargauUkraine', 'https://t.me/BaselUkraine',
#        'https://t.me/BernUkraine', 'https://t.me/BielBienneUkraine',
#        'https://t.me/GeneveUkraine', 'https://t.me/IntegrationBernCH',
#        'https://t.me/KasselUkrainehilfen', 'https://t.me/LousanneUkraine',
#        'https://t.me/LuzernUkraine',
#        'https://t.me/SolidarityUkraineBremen',
#        'https://t.me/StGallenUkraine', 'https://t.me/SwissUA',
#        'https://t.me/ThurgauUkraine', 'https://t.me/TicinoLuganoUkraine',
#        'https://t.me/UASchweiz', 'https://t.me/UkrainerInBasel',
#        'https://t.me/UkrainianSwitzerland', 'https://t.me/ValaisUkraine',
#        'https://t.me/Zh_helps_UA_mums', 'https://t.me/austriaukr',
#        'https://t.me/autotransport_wien', 'https://t.me/bielefeldhelps',
#        'https://t.me/campax_ukraine_help_switzerland',
#        'https://t.me/cologne_help', 'https://t.me/duisburgukraine',
#        'https://t.me/fribourg1', 'https://t.me/germanyhelpsukraine',
#        'https://t.me/hamburg_help', 'https://t.me/hamburg_hilft',
#        'https://t.me/helpUkraine_Gemany',
#        'https://t.me/help_in_Nuremberg_UA',
#        'https://t.me/help_people_fromUkraine',
#        'https://t.me/helpfulinfoforua',
#        'https://t.me/helppetsfromukraine',
#        'https://t.me/job_sw_ukrainians', 'https://t.me/naym_austria',
#        'https://t.me/pomosh_Germany_Chemnitz_Ukraine',
#        'https://t.me/refugees_in_Germany',
#        'https://t.me/refugeesinAustria',
#        'https://t.me/refugeesinSwitzerland',
#        'https://t.me/seep_helpukrainians',
#        'https://t.me/suport_ukraine_in_bremen',
#        'https://t.me/ukc_munich_volunteer', 'https://t.me/ukr_de_essen',
#        'https://t.me/ukraine_helfen_mainz',
#        'https://t.me/ukraine_karlsruhe', 'https://t.me/ukraine_reborn',
#        'https://t.me/ukrainehelpberlin', 'https://t.me/ukrainer_basel',
#        'https://t.me/ukrainerinleipzig', 'https://t.me/zh_back_ukraine',
#        'https://t.me/zh_helps_UArefugee',
#        'https://t.me/zh_helps_UArefugees',
#        'https://t.me/zh_helps_logistics', 'https://t.me/zh_helps_ukraine',
#        'https://t.me/zh_housing', 'https://t.me/zurich_hb_help'],
#       dtype=object)

# %%
dt_s = ['https://t.me/AargauUkraine', 'https://t.me/BaselUkraine',
       'https://t.me/BernUkraine', 'https://t.me/BielBienneUkraine',
       'https://t.me/GeneveUkraine', 'https://t.me/IntegrationBernCH',
       'https://t.me/KasselUkrainehilfen', 'https://t.me/LousanneUkraine',
       'https://t.me/LuzernUkraine',
       'https://t.me/SolidarityUkraineBremen',
       'https://t.me/StGallenUkraine', 'https://t.me/SwissUA',
       'https://t.me/ThurgauUkraine', 'https://t.me/TicinoLuganoUkraine',
       'https://t.me/UASchweiz', 'https://t.me/UkrainerInBasel',
       'https://t.me/UkrainianSwitzerland', 'https://t.me/ValaisUkraine',
       'https://t.me/Zh_helps_UA_mums', 
       'https://t.me/bielefeldhelps',
       'https://t.me/campax_ukraine_help_switzerland',
       'https://t.me/cologne_help', 'https://t.me/duisburgukraine',
       'https://t.me/fribourg1', 'https://t.me/germanyhelpsukraine',
       'https://t.me/hamburg_help', 'https://t.me/hamburg_hilft',
       'https://t.me/helpUkraine_Gemany',
       'https://t.me/help_in_Nuremberg_UA',
       'https://t.me/help_people_fromUkraine',
       'https://t.me/helpfulinfoforua',
       'https://t.me/helppetsfromukraine',
       'https://t.me/job_sw_ukrainians', 
       'https://t.me/pomosh_Germany_Chemnitz_Ukraine',
       'https://t.me/refugees_in_Germany',
       'https://t.me/refugeesinSwitzerland',
       'https://t.me/seep_helpukrainians',
       'https://t.me/suport_ukraine_in_bremen',
       'https://t.me/ukc_munich_volunteer', 'https://t.me/ukr_de_essen',
       'https://t.me/ukraine_helfen_mainz',
       'https://t.me/ukraine_karlsruhe', 'https://t.me/ukraine_reborn',
       'https://t.me/ukrainehelpberlin', 'https://t.me/ukrainer_basel',
       'https://t.me/ukrainerinleipzig', 'https://t.me/zh_back_ukraine',
       'https://t.me/zh_helps_UArefugee',
       'https://t.me/zh_helps_UArefugees',
       'https://t.me/zh_helps_logistics', 'https://t.me/zh_helps_ukraine',
       'https://t.me/zh_housing', 'https://t.me/zurich_hb_help']

# %%
df = df[df.chat.isin(dt_s)]

# %%
df.to_csv('../data/telegram/DACH/df_clean.csv', index=False)
# Out:
# (1513979, 3)

# %%
with open("../data/stopwords/country_stopwords.txt") as file: #load list of countries
    country_stopwords = [line.rstrip() for line in file]

def remove_countries(text, country_stopwords):
    for country in country_stopwords:
        if country in text:
            # counter_country += 1
            text = re.sub(country, '', text) #check if "COUNTRY" is better as replacement
            text = text.replace("  ", " ")
    return text

utterances = ["Refugees in Germany are facing challenges", "Refugees in Poland are facing different challenges"]
counter_country = 0

# %%
text_to_analyse_list = [remove_countries(text=utterance, country_stopwords=country_stopwords) for utterance in utterances]

# %%
text_to_analyse_list[2:]
# Out:
# []

# %% [markdown]
# # Exploratory Analysis

# %%
# df = pd.read_csv('../data/telegram/Europe/df.csv')
df['messageText'] = df['messageText'].str.replace(u'\n', ' ')
print(df.shape)
# df.replace('...', np.nan, inplace=True) 
df.dropna(subset=['messageText'],inplace=True) #what does it mean if messageSender empty
# df.messageSender = df.messageSender.astype(int)
print(df.shape)
df.drop_duplicates(keep='first',inplace=True)
print(df.shape)
# df.drop_duplicates(subset=['messageText', 'messageSender', 'messageDatetime'], keep='first',inplace=True)
print(df.shape)
df["messageText"] = df['messageText'].str.split().str.join(' ')

# dfZ = pd.concat([df[df.chat.isin(['https://t.me/zh_helps_ukraine', 'https://t.me/zh_helps_UArefugee', 'https://t.me/zurich_hb_help', 'https://t.me/zh_housing', 'https://t.me/Zurich_UA', 'https://t.me/zh_helps_UArefugees'
#                  'https://t.me/Zh_helps_UA_mums', 'https://t.me/zh_back_ukraine', 'https://t.me/zh_helps_logistics'])], df.loc[df['messageText'].str.contains("Цюрих|Zurich|Zürich", case=False)]])
# dfZ.drop_duplicates(keep='first',inplace=True)
# # df = df[df.chat=="https://t.me/refugeesinSwitzerland"]
# # dfZ = dfZ[dfZ.chat=="https://t.me/refugeesinSwitzerland"]
# df['messageText'].to_csv("../data/BERTopicInput.csv", header=False, index=None)
# df[(df['messageText'].str.len() > 50) & (df['messageText'].str.len() < 50)].to_csv("../data/BERTopic100CharMin2500.csv",  index=None)
# df[(df['messageText'].str.len() >= 250) & (df['messageText'].str.len() <= 2500)]['messageText'].to_csv("../data/BERTopicInput250CharMin2500CharMax.csv",  header=False, index=None)
# Out:
# (778930, 3)
# (778930, 3)
# (778930, 3)
# (778930, 3)

# %%
df.loc[df['messageText'].str.contains("Приймаючі сім'ї|Приймаючі родини|Приймаюча сім'я|Принимающие семьи|Семьи принимающих гостей|Gastfamilien|Gastfamilie|host family", case=False)][["chat", 'messageID', 'messageReplyID','messageDatetime', 'messageViews', 'messageForwards','messageReactions', 'messageText']].to_csv("../raphaelGastFamilien.csv")

# %%
df.columns
# Out:
# Index(['chat', 'messageSender', 'messageID', 'messageReplyID',
#        'messageDatetime', 'messageViews', 'messageForwards',
#        'messageReactions', 'messageText'],
#       dtype='object')

# %%
df[df.index==166941].messageText.values[0]
# Out:
# 'СИСТЕМА ОБЩЕСТВЕННОГО ТРАНСПОРТА В КАНТОНЕ ЦЮРИХ (ZVV) Часть 1✏️С 1 июня 2022 года отменяется бесплатный проезд в общественном транспорте для лиц со статусом защиты «S».✏️ Ранее мы уже писали о том, как можно сэкономить на проезде в общественном транспорте 🚌 при помощи HalbTax, Tageskarte и т.д. ✏️Теперь мы хотим рассказать Вам как пользоваться системой общественного транспорта Zürcher Verkehrsverbund (ZVV) в кантоне Цюрих.✏️ Вся сеть ZVV поделена на тарифные зоны. При этом зоны 110 Цюрих (Zürich) и 120 Винтертур (Winterthur) считаются за 2 зоны каждая, так как сеть общественного транспорта в этих городах значительно плотнее.📎 Здесь Вы можете ознакомиться со схемой всех тарифных зон в кантоне Цюрих: [https://www.zvv.ch/zvv-assets/abos-und-tickets/zonen/2021-2501-tarifzonen.pdf](https://www.zvv.ch/zvv-assets/abos-und-tickets/zonen/2021-2501-tarifzonen.pdf)✏️ Для коротких поездок Вы можете использовать следующие билеты:▫️В пределах Gemeinde (кроме городов: Цюрих и Винтертур) - Lokalnetz.▫️Для коротких поездок по Цюриху или Винтертуру - Kurzstrecken (поездки до 30 минут и только в пределах города);✏️Билеты на общественный транспорт продаются по 2 тар
# 366002  Если какие-то вопросы, обращайтесь. Чем смогу ...
# 366006  Здравствуйте) и мы в Роршах) я с сыном 9 лет и...
# 366013  3 месяца бесплатных языковых курсов для украин...
#
# [208298 rows x 4 columns]

# %%
df.loc[df['messageText'].str.contains("Staatskanzlei", case=False)].messageText.to_csv("../data/results/sentenceStaatskanzlei.csv")

# %%
import matplotlib.pyplot as plt 

dfWeek = pd.DataFrame(df['messageDatetime'].apply(lambda x: pd.to_datetime(x).isocalendar()[1]).value_counts()).merge(dfZ['messageDatetime'].apply(lambda x: pd.to_datetime(x).isocalendar()[1]).value_counts(), left_index=True, right_index=True).sort_index()

X = dfWeek.index
nrMessagesPerWeekAll = dfWeek.messageDatetime_x
nrMessagesPerWeekZurich = dfWeek.messageDatetime_y
  
X_axis = np.arange(len(X))
plt.figure(figsize=(20,10))
plt.bar(X_axis - 0.2, nrMessagesPerWeekAll, 0.4, label = 'All Messages')
plt.bar(X_axis + 0.2, nrMessagesPerWeekZurich, 0.4, label = 'Messages Zurich')
  
plt.xticks(X_axis, X)
plt.xlabel("Week")
plt.ylabel("Messages")
plt.title("Number of Messages in Telegram Channels")
plt.legend()
plt.savefig('../plots/allTelegramGroups.jpg')
# plt.show()

# %%
# dfWeek = pd.DataFrame(df['messageDatetime'].apply(lambda x: pd.to_datetime(x).isocalendar()[1]).value_counts()).merge(dfZ['messageDatetime'].apply(lambda x: pd.to_datetime(x).isocalendar()[1]).value_counts(), left_index=True, right_index=True).sort_index()

X = df.messageSender.value_counts()[:25].index
nrMessagesPerWeekAll = df.messageSender.value_counts()[:25]
# nrMessagesPerWeekZurich = dfWeek.messageDatetime_y
  
X_axis = np.arange(len(X))

plt.figure(figsize=(20,10))
plt.bar(X_axis - 0.2, nrMessagesPerWeekAll, 0.4, label = 'All Messages')
# plt.bar(X_axis + 0.2, nrMessagesPerWeekZurich, 0.4, label = 'Messages Zurich')
  
plt.xticks(X_axis, X, rotation=-90)
plt.xlabel("Account ID")
plt.ylabel("Messages")
plt.title("Number of Messages by Account")
plt.legend()
plt.savefig('../plots/allTelegramGroupsMostMessagesBySingleAccountTop25.jpg')

# %%
df.loc[df['messageText'].str.contains("Staatskanzlei", case=False)
# Out:
#   Input In [43]
#     df.loc[df['messageText'].str.contains("Цюрих|Zurich|Zürich", case=False)
#                                                                             ^
# SyntaxError: unexpected EOF while parsing

# %%
df[df.messageSender==1335905103].messageText
# Out:
# 1         Спрашивайте у SEM по вашему случаю. Все индиви...
# 12        ☝🏻Все объявления с предоставлением товаров/усл...
# 16        Уже много раз рассказывала и снова повторюсь:С...
# 21        И каким образом вы местных соседей подключите?...
# 23        По факту таких законов нет. Есть информация, ч...
#                                 ...
# 240243    Из личных наблюдений. Тут дорого, строго и ост...
# 240248    Пособия для Украинцев в Швейцарии Будут ли вып...
# 240386    Действительно вам бы в Лугано, например😍 с ита...
# 240414    Тут даже не в воровать дело. Просто, например,...
# 240650    Мне сказали, что собаку старше 5 или даже 3х л...
# Name: messageText, Length: 4779, dtype: object

# df.messageSender.value_counts().reset_index()[:1000].to_csv('../data/results/1000MostActiveUsers.csv', index=None, header=['sender_id', 'messages_send'] )
df.messageSender.value_counts()[:1000]
# Out:
# 1335905103    4779
# 480572696     3092
# 5228353505    2588
# 76712299      2567
# 5025746576    2194
#               ...
# 260947514       51
# 2002863600      51
# 1772162435      51
# 744070252       51
# 767572491       51
# Name: messageSender, Length: 1000, dtype: int64

# %%
df[df.messageSender==1335905103].messageText[1]
# Out:
# 'Спрашивайте у SEM по вашему случаю. Все индивидуально. Одной девушке из Германии ответили так: https://t.me/refugeesinSwitzerland/123014'

# %%
from collections import Counter
from urllib.parse import urlparse

baselevel=3

def retrieve_base_url(url, baselevel=0):
    if baselevel==0:
        try:
            parseresult = urlparse(url)
            url_clean = parseresult.scheme + '//' + parseresult.netloc
            return url_clean
        except:
            ValueError
    if baselevel>=1:
        try:
            parseresult = urlparse(url)
            url_clean = parseresult.scheme + '//' + parseresult.netloc + '/' + '/'.join(parseresult.path.split('/')[1:baselevel+1])
            print(url_clean)
            return url_clean
        except:
            ValueError



df['messageURL'] = df['messageText'].apply(lambda x: re.findall(r'(https?://[^\s]+)', x))
urlList = [x for xs in df['messageURL'] for x in xs]
# pd.Series(urlList).value_counts().to_csv("../data/results/mostSharedLinks.csv")
urlTelegramList = [url for url in urlList if url.startswith("https://t.me")]
pd.Series(urlTelegramList).value_counts().to_csv("../data/telegram/DACH/mostSharedLinksTelegramGroups.csv")
urlBaseLevelList = [retrieve_base_url(url=url,baselevel=baselevel) for url in urlList]
# pd.Series(urlBaseLevelList).value_counts().to_csv(f"../data/results/mostSharedBaseLevel{baselevel}Links.csv")
# Out:
# https//goo.gl/maps/fsU5js8EdVwo9sDNA
# https//goo.gl/maps/dt5xBPEMrephcyVv7
# https//goo.gl/maps/qT16Y3YUwwWoVyWt5
# https//www.instagram.com/p/Ca4RJMwIkY1/
# https//facebook.com/events/s/%D0%B2%D0%B8%D0%B4%D0%B0%D1%87%D0%B0-%D0%BE%D0%B4%D1%8F%D0%B3%D1%83-%D0%B4%D0%BB%D1%8F-%D0%B1%D1%96%D0%B6%D0%B5%D0%BD%D1%86%D1%96%D0%B2-%D0%B7-%D1%83%D0%BA
# https//t.me/UASchweiz,
# https//t.me/UAhelpCHbot
# https//www.caritas-aargau.ch/hilfe-finden/fluechtlingsberatung
# https//www.ag.ch/media/kanton_aargau/dgs
# https//www.integrationregionbaden.ch/
# https//www.integrationregionbaden.ch/integration-region-baden/information/deutsch-lernen.html
# https//www.integrationregionbaden.ch/integration-region-baden/veranstaltungen.html/2186
# https//www.integrationregionbaden.ch/integration-region-baden/beratung.html/2177
# https//www.integrationregionbaden.ch/integration-region-baden/veranstaltungen.html/2185
# https//www.gesellschaft-aarau.ch/integration/integrationsfoerderung.html/505
# https//www.aargauerzeitung.ch/aargau/kanton-aargau/aargau-ukraine-news-218-fluechtende-aus-der-ukraine-in-den-aargau-zugeteilt-aarau-bietet-zeitnah-28-wohnungen-fuer-fluechtlinge-an-ld.2258255
# https//t.me/UASchweiz
# https//t.me/swiss_ukr_help
# https//t.me/refugeesinSwitzerland
# https//t.me/help_people_fromUkraine
# https//t.me/seep_helpukrainians
# https//kirchen-helfen.ch/
# https//t.me/zh_helps_UArefugee
# https//t.me/zh
# https//maps.apple.com/
# https//t.me/UAhelpCHbot
# https//docs.google.com/forms/d/e
# https//maps.app.goo.gl/sMzCamGD9yeJ4r837
# https//t.me/UAhelpCHbot
# https//support.apple.com/ru-ru/HT201389
# https//krly05.github.io/SwissUA/
# https//www.stepstone.at/wp-content/uploads/2020
# https//www.deepl.com/translator
# https//www.superjob.ru/pro/5052/
# https//g.co/kgs/ckpuJr
# https//goo.gl/maps/UWXPj5vw3aVJZgNg6.
# https//t.me/naym_info)👈
# https//kambly.com/de/
# https//t.me/+juXk9rh_XuoyMGE0
# https//t.me/essenfueralle2020
# https//hopehouse.heilsarmee.ch/hope-kleider/
# https//www.facebook.com/events/713111153203571/
# https//g.co/kgs/duHiwg
# https//g.co/kgs/EV7eEN
# https//goo.gl/maps/FQYdbTQki1L8kHrn8э
# https//www.jobs.ch/de/stellenangebote/detail
# https//t.me/SolothurnUkraine
# https//colorbar.ch/
# https//www.zoobasel.ch/fr/zoobasel/faq
# https//www.tierpark-bern.ch/mobile-de.php
# https//zoos.ch/
# https//www.zoo-alpin.ch/
# https//www.zoo.ch/de
# https//youtu.be/QMbAoUFsSVw
# https//youtu.be/AgWFs78ADqg
# https//t.me/pomoshukrainaa
# https//maps.app.goo.gl/R51RyAUQAGd3dww38
# https//www.facebook.com/groups/1397765664070800/
# https//www.udemy.com/course/novalgermana1/
# https//www.bag.admin.ch/bag/de/home
# https//maps.app.goo.gl/xyJcToBXj3QiUHms7
# https//maps.app.goo.gl/qC5SMxZV68jReARLA
# https//maps.app.goo.gl/ho9fmnLjaVzC2e9MA
# https//www.jobcloud.ch/c/en/ukraine-friendly-jobs-switzerland
# https//maps.app.goo.gl/WhDpsnhNiMRG1eKG9
# https//goo.gl/maps/hR95gQdcvJUaRMYJ9.
# https//goo.gl/maps/bsbVvsnFXsdxB8tq8
# https//goo.gl/maps/zHfc5v4ZqNnAcr2G9.
# https//goo.gl/maps/8c8F7mZrboxwUKQz5.
# https//goo.gl/maps/mw8zAbVG4hgFjWx79
# https//www.zh.ch/content/dam/zhweb
# https//www.facebook.com/groups/1397765664070800/
# https//t.me/uni_deutsch_anfang
# https//www.instagram.com/p/CcN-bNRNMYQ/
# https//us04web.zoom.us/j/5941282459
# https//buecher-brocky.ch/kontakt-2/
# https//www.zeiss.ua/vision-care/_campaigns/direct-eye-care-support.html
# https//t.me/pomoshukrainaa
# https//toogoodtogo.ch/de-ch
# https//www.srk-aargau.ch/sites/default/files
# https//job-werkstatt.ch/
# https//www.ag.ch/de/verwaltung/dvi
# https//t.me/zh_helps_UArefugee
# https//t.me/ZurichUkraine
# https//g.page/werkraum21
# https//t.me/swiss_ua_freechat.
# https//t.me/UASchweiz
# https//t.me/AargauUkraine/3692
# https//t.me/zh_helps_ukraine/486
# https//maps.app.goo.gl/4xPMVH2PbDRvNj2g8
# https//www.srk-aargau.ch/
# https//www.local.ch/de/d/olten
# https//www.yallo.ch/en/shop
# https//www.yallo.ch/en/ukraine
# https//www.facebook.com/102328622410189/posts/106362212006830
# https//www.blick.ch/politik/kantoenligeist-bei-sozialhilfe-fuer-ukrainer-st-gallen-laesst-fluechtlinge-fuer-gastfamilien-zahlen-id17398843.html
# https//www.stadt-zuerich.ch/content/aoz/de
# https//www.sem.admin.ch/sem/de/home
# https//produkte.migros.ch/m-budget-tricolore
# https//shop.migros.ch/en/product/mo
# https//www.bazg.admin.ch/bazg/en/home
# https//www.bazg.admin.ch/bazg/en/home
# https//www.nbi-ngf.ch/pdf/up/Recommendation%20on%20UA%20PDF%20Green%20Cards%20and%20CoB%20information%20leaflets%20for%20drivers%20of%20UA%20registered%20vehicles.pdf
# https//gc.mtsbu.ua/MTSBU_Pages/Tree.aspx
# https//jysk.ch/de/schlafzimmer/bettwasche
# https//radikal-liquidationen.ch/standorte/
# https//t.me/BeautySwitzerland
# https//tickets.fcb.ch/shop
# https//www.ag.ch/de/verwaltung/dvi
# https//www.stadt-zuerich.ch/content/aoz/de
# https//t.me/seep_helpukrainians/226
# https//www.fressnapf.ch/de/)
# https//www.fressnapf.ch/de/uber-uns/filialen
# https//www.fressnapf.ch/de/)
# https//www.fressnapf.ch/de/uber-uns/filialen
# https//bit.ly/36QqX5G
# https//tickets.fcb.ch/shop
# https//www.coopvitality.ch/de/b-braun-chlorhexidine-2-ungefarbt-100-ml.html
# https//www.facebook.com/groups/1397765664070800/permalink
# https//skos.ch/fr/les-normes-csias/juridique
# https//www.sem.admin.ch/sem/de/home
# https//www.sem.admin.ch/sem/de/home
# https//www.sem.admin.ch/sem/de/home
# https//www.change.org/p/humanitarian-corridors-for-civilians-and-wounded-in-mariupol
# https//www.schweizer-wanderwege.ch/
# https//www.schweizmobil.ch/de/wanderland.html
# https//wegwandern.ch/
# https//www.myswitzerland.com/de-ch/erlebnisse/sommer-herbst
# https//www.zuerich.com/de/besuchen/wandern
# https//www.komoot.de/guide/329/wandern-rund-um-zuerich
# https//swissfamilyfun.com/swiss-spring-hikes-visitors/
# https//www.myswitzerland.com/en-ch/experiences/summer-autumn
# https//grillstelle.ch/.
# https//t.me/AargauUkraine/4347
# https//www.facebook.com/groups/1397765664070800/permalink
# https//www.fiz-info.ch/de/Willkommen
# https//www.20min.ch/video/deutschschweizer-lockt-ukrainerinnen-ins-erotikmilieu-133929211453
# https//www.roggenhausen.ch/jo/
# https//www.baden.ch/de/leben-wohnen/leben
# https//www.ag.ch/de/themen/asyl-und-fluechtlingswesen
# https//treffpunktwettingen.ch/wordpress/
# https//treffpunktwettingen.ch/wordpress/
# https//www.myswitzerland.com/en-ch/experiences/experience-tour
# https//nashagazeta-ch.turbopages.org/nashagazeta.ch/s/news
# https//t.me/Zh_helps_UA_mums/6522
# http//tiny.cc/eurordis](http://tiny.cc
# https//t.me/+cBVMnNwdUk9iYmM0
# https//t.me/DeutschFuerDieUkraine/42
# https//www.facebook.com/groups/winterthurhelpsrefugees/permalink
# https//www.aargauerzeitung.ch/aargau/freiamt/bremgarten-unterbringung-von-ukrainischen-fluechtlingen-stadt-bildet-taskforce-und-sucht-leerstehende-wohnungen-ld.2281869
# https//maps.app.goo.gl/P4Gh1EGj5sQHhJut7
# https//takwork.ch/ru/-2/teilzeit-mitarbeiterin-reinigung
# https//www.beratungsdienste.ch/
# https//www.integrationaargau.ch/angebote
# https//www.gesellschaft-aarau.ch/public/upload/assets
# https
# https//t.me/zh_helps/14676
# https//maps.app.goo.gl/dE6DR7tAMVXDCMa38
# https//maps.app.goo.gl/ywmduHBXHPKW2RJm7
# https//swissfamilyfun.com/map-of-hikes-and-activities/
# https//fb.watch/cSuR-oZxbe/
# https//goo.gl/maps/mC2digPtXC9SZPAz5
# https//www.googleadservices.com/pagead/aclk
# https//play.google.com/store/apps/details
# https//apps.apple.com/us/app/profital
# https//support.apple.com/ru-ru/HT201389
# https//apps.apple.com/ch/app/wetter-alarm-schweizer-meteo
# https//telegra.ph/file/5ea433e76f7c3241807f3.jpg)🦄Актуальні
# https//bit.ly/35CJ26O).
# https//bit.ly/3F53MBg),
# https//bit.ly/3F4hqVv)
# https//bit.ly/3y1US6e)
# https//bit.ly/3kwMjIw)й
# https//bit.ly/3JEN0d4)
# https//bit.ly/3LxJnYh)
# https//bit.ly/3kOwbCB),
# https//bit.ly/3y5Ucg2):
# https//bit.ly/3EdpZN5)
# https//bit.ly/3y848Wl),
# https//bit.ly/3LCIs8Q)
# https//bit.ly/3OPCZxm)
# https//bit.ly/39kEQKe)
# https//www.meisterschwanden.ch/gemeinde/verwaltung/abteilungen
# https//www.krebsliga.ch/krebspatienten-aus-der-ukraine
# https//www.swisscom.ch/de/privatkunden/ukraine-ukr.html
# https//eventfrog.ch/de/p/gruppen
# https//t.me/kalush_off)****🇺🇦
# https//t.me/+VT4ABoX8ETA4OTI6)**
# https//switzerland.mfa.gov.ua/konsulski-pitannya/pasportni-diyi/2222-passport
# https//www.fundsachenverkauf.ch/
# https//www.swisscom.ch/de/privatkunden/produkte
# https//revendo.ch/kaufen/smartphone-gebraucht-guenstig-kaufen/
# https//t.me/UAhelpCHbot
# https//eventfrog.ch/de/p/gruppen
# https//t.me/+fldgu7Y9sYMzNmUy
# https//t.me/AargauUkraine/6479.
# https//www.tischlein.ch/lebensmittel-beziehen/
# https//www.ag.ch/de/themen/asyl-und-fluechtlingswesen
# https//www.homegate.ch/mieten/3001476106
# https//www.facebook.com/groups/dua0630/permalink
# https//g.co/kgs/YuAuca
# https//g.co/kgs/MxJe6G
# https//krly05.github.io/SwissUA/
# https//www.migros.ch/de/product/513851200000
# https//www.migros.ch/de/product/526210000000
# https//www.migros.ch/de/product/512025200000
# https//www.aaz-aarau.ch/services/sos-zahnarzt
# https//www.aarau.ch/politik-verwaltung/einwohnergemeinde/soziale-dienste.html
# https//www.ag.ch/media/kanton-aargau/themen
# https//www.ag.ch/media/kanton-aargau/themen
# https//www.ag.ch/de/verwaltung/dvi
# https//t.me/zh_helps_ukraine/620
# https//m.facebook.com/events/487688463107710
# https//repair-cafe.ch/de/cafes/repair-cafe-aarau
# https//www.zeiss.ua/vision-care/_campaigns/direct-eye-care-support.html
# https//repair-cafe.ch/de/events
# https//www.migros.ch/de/search
# https//t.me/stomatologch
# https//t.me/swiss_ukr_help
# https//switzerland.mfa.gov.ua/konsulski-pitannya/pasportni-diyi
# https//www.ag.ch/de/verwaltung/dgs
# https//www.guidle.com/de/ausfluege/stansstad
# https//batmaid.ch/en/become-a-batmaid/
# https//aids.ch/de/haeufigste-fragen/schutz-und-risiko
# https//phzh.ch/de/Weiterbildung/weiterbildungssuche
# https//www.stadtbibliothekaarau.ch/aktivitaeten/fremdsprachige-geschichtenstunden/ukrainisch.html
# https//switzerland.mfa.gov.ua/)
# https//goo.gl/maps/K8HGGPxskHAV75fL7
# https//www.npg-rsp.ch/de/projekte/10-schritte-fuer-psychische-gesundheit.html
# https//facebook.com/events/s/mutter-kind-yoga-fur-frauen-un
# https//forms.gle/3AvLTTPCUV2hTEeJ8
# https//fb.me/e/3b11tbjq4
# https//www.instagram.com/p/Cdai-Fbqc3v/
# https//job-werkstatt.ch/
# https//www.becc.admin.ch/becc/public/bvz
# https//ukraine.epfl.ch/:
# https//ethz.ch/services/en/news-and-events
# https//www.unifr.ch/home/en/solidarity-ukraine
# https//www.unibas.ch/de/Aktuell/Ukraine.html:
# https//www.hesge.ch/head/en/event
# https//www.facebook.com/100023066118368/posts/901017947343734
# https//docs.google.com/spreadsheets/d/1HqTKukfJGpmowQnSh4CoFn3T6HXcNS1T1pK-Xx9CknQ
# https//www.fhnw.ch/en/startseite
# https//www.zhdk.ch/en/news/solidarity-with-ukraine-contact-points-and-actions-5052
# https//krly05.github.io/SwissUA/
# https//t.me/zh_helps_UArefugee/24195
# https//goo.gl/maps/Xe9ULsX3kbZ15TyL7
# https//www.post.ch/de
# https//www.facebook.com/102328622410189/posts/127764136533304
# https//us02web.zoom.us/meeting/tZMpc--oqT4uGtT3VqdUALJoUDoF2E7OmEPU/ics
# https//us02web.zoom.us/j/87446075400
# https//t.me/+4qfE162JsGg3YThi
# https//instagram.com/sys_svetlana
# https//www.sbb.ch/en/station-services/at-the-station
# https//m.youtube.com/watch
# https//www.workselection.com/help-for-ukraine/
# https//g.co/kgs/ygtDrV
# https//www.abbts.ch/
# https//www.ag.ch/de/themen/asyl-und-fluechtlingswesen
# https//www.ag.ch/de/verwaltung/bks
# https//www.heartbeat-aarau.ch/kalender/pferderennen-im-schachen-2022/27016
# https//www.kindermuseum.ch/events/internationaler-museumstag/
# https//ch.indeed.com/m/viewjob
# https//www.workselection.com/help-for-ukraine/
# https//m.facebook.com/story.php
# https//www.idealo.de/
# https//de.sarenza.ch/schuhe-taschen
# https//www.facebook.com/anastasia.kartasheva
# https//t.me/UkraineSwissBusinessA
# https//t.me/+4qfE162JsGg3YThi
# https//www.migros.ch/en/product/mo
# https//t.me/zurich_hb_help
# https//t.me/swiss_ukr_help/22537
# https//www.fluechtlingshilfe.ch/fileadmin/user_upload/Aktiv_werden
# https//lostandfound.sbb.ch/home/sbb/SBB
# https//t.me/AargauUkraine/7953
# https//ch.indeed.com/m/viewjob
# https//www.workselection.com/help-for-ukraine/
# https//maps.app.goo.gl/fpoAZwcsdxr5Gh4r5
# https//www.nachhaltigleben.ch/food/erdbeeren-selber-pfluecken-auf-diesen-feldern-in-der-schweiz-4092
# https//t.me/zh_helps_UArefugee
# https//t.me/zh_back_ukraine
# https//t.me/swissfood
# https//g.co/kgs/fhWjr7
# https//www.sem.admin.ch/sem/de/home
# https//t.me/stomatologchgroup
# https//www.ag.ch/media/kanton-aargau/dvi
# https//www.integrationaargau.ch/information/integrationsplattform/
# https//www.facebook.com/225760547855235/posts/pfbid02N4uyzbhG23Vopp7d3MX9Gn1fXHsgGkJYUrJXwAxVN5HtRvbjoiUWowBFcX2fbHWKl
# https//t.me/AargauUkraine/13107
# https//www.bazg.admin.ch/bazg/de/home
# https//solidariteukraine.ch/uk/%D0%B7%D0%B0%D0%B3%D0%B0%D0%BB%D1%8C%D0%BD%D0%B0-%D1%96%D0%BD%D1%84%D0%BE%D1%80%D0%BC%D0%B0%D1%86%D1%96%D1%8F/
# https//goo.gl/maps/uXZcLAjNUzZqqKWa8
# https//maps.app.goo.gl/jjPYMwTKCD8ZQ99Z6
# https//maps.app.goo.gl/kn7g35mtAsGHGWH16
# https//www.ksa.ch/ihre-nachricht-ans-ksa
# https//www.augenaerzte-aarau.ch/
# https//wettingen2022.ch/programm/
# https//www.instagram.com/p/CemVVgyt2tf/
# https//posts.naym.me/3tEDscS
# https//t.me/naym_info)
# https//maps.app.goo.gl/MfcPYwJxCcGiJzQU7
# https//www.fcrohr.ch/cms/index.php
# https//www.fcrohr.ch/cms/index.php/schnuppertraining
# https//t.me/+tNif-7U3Jg81NGUy
# https//www.google.com/search
# https//stadtbibliothek.baden.ch/
# https//www.uzh.ch/cmsssl/en/studies
# https//www.degrees.uzh.ch/en/master/
# https//www.degrees.uzh.ch/en/phd/
# https//www.uzh.ch/cmsssl/dam/jcr:3cf51d70-d77f-4a0d-b7a6-cd76314d77ee
# https//www.scholarsatrisk.org/in-solidarity-with-ukraine/
# https//euraxess.ec.europa.eu/ukraine
# https//www.uzh.ch/cmsssl/en/about
# https//www.uzh.ch/cmsssl/en/about
# https//www.uzh.ch/cmsssl/en/about
# https//visitukraine.today/ru/blog/462
# https//t.me/+u3vpZyDvWeJhNDli
# https//recycling-map.ch/de/sammelgueter/material.php
# https//www.20min.ch/story/die-schoensten-versteckten-bergseen-der-schweiz-502882548526
# https//instagram.com/faustpharmacie
# https//www.ag.ch/de/verwaltung/dvi
# https//switzerland.mfa.gov.ua/dokument-pro-identifikaciyu-osobi
# https//t.me/Lovely_Job_in_Switzerland_Past
# https//youtube.com/c/lingoniGERMAN](https:/
# https//youtube.com/channel/UCUOL7D73isdBOx2XzuihIJQ](https:/
# https//youtube.com/user/andreathionville](https:/
# https//youtube.com/c/%D0%90%D0%BB%D0%B5%D0%BA%D1%81%D0%B0%D0%BD%D0%B4%D1%80%D0%91%D0%B5%D0%BA%D0%BA%D0%B5%D1%8021](https:/
# https//youtube.com/c/%D0%90%D0%BB%D0%B5%D0%BA%D1%81%D0%B0%D0%BD%D0%B4%D1%80%D0%91%D0%B5%D0%BA%D0%BA%D0%B5%D1%8021](https:/
# https//youtube.com/c/DeutschmitMarija](https:/
# https//youtube.com/channel/UCYvWsIn4Dc3GGAv8rymiG6Q](https:/
# https//learngerman.dw.com/de/nicos-weg/c-36519687](https:
# https//t.me/+QGFRHfCRPLNiOWMy
# https//t.me/zh_helps_ukraine](https://t.me
# https//www.gesellschaft-aarau.ch/public/upload/assets
# https//www.brugg.ch/public/upload/assets
# https//seep.ch/
# https//seep.ch/
# https//www.gesellschaft-aarau.ch/public/upload/assets
# https//www.svsa.sid.be.ch/content/dam/svsa_sid
# https//www.svsa.sid.be.ch/de/start.html
# https//www.svsa.sid.be.ch/content/dam/svsa_sid
# https//www.svsa.sid.be.ch/de/start.html
# https//www.gesellschaft-aarau.ch/public/upload/assets
# https//eventfrog.ch/de/p/konzert
# https//www.gesellschaft-aarau.ch/public/upload/assets
# https
# https//t.me/zh_helps_UArefugee
# https//t.me/zh_back_ukraine
# https//www.heks.ch/was-wir-tun/rechtsberatungsstelle-fuer-asylsuchende-aargau
# https//www.frauenhaus-ag-so.ch/
# https//www.ahg-aargau.ch/
# https//www.frauenzentrale-ag.ch/.
# https//www.bif-frauenberatung.ch/.
# https//www.opferhilfe-schweiz.ch/de/kurzinformationen-uber-die-opferhilfe/information-auf-russisch
# https//www.bif-frauenberatung.ch/file/download/50
# https//www.swissinfo.ch/rus/товары-и-цены_швейцарцы-любят-шопинг-в-ближнем-зарубежье/43378126
# https//www.ag.ch/de/verwaltung/dfr
# https//www.ag.ch/media/kanton-aargau/dfr
# https//ukrpage.ch/ua/jobseekers-preform)
# https//ukrpage.ch/ua/jobseekers-preform)
# https//ukrpage.ch/ua/jobseekers-preform
# https//t.me/ukrpage_jobs)
# https//www.facebook.com/groups/1397765664070800/
# https//docs.google.com/forms/d/e
# https//www.facebook.com/groups/1397765664070800/
# https//www.ag.ch/de/themen/asyl-und-fluechtlingswesen
# https//www.sbfi.admin.ch/dam/sbfi/de
# https//www.sbfi.admin.ch/sbfi/de/home
# https//www.sbfi.admin.ch/sbfi/de/home
# https//www.kulturlegi.ch/aargau/angebote/angebot-waehlen).
# https//t.me/swiss_ukr_help/32754
# https//www.google.com/maps/dir/
# https//www.zh.ch/de/migration-integration/asyl
# https//www.sem.admin.ch/dam/sem/de
# https//velostation-aarau.ch/
# http//UKRPAGE.CH/
# https//ukrpage.ch/ua/jobseekers-preform
# https//ukrpage.ch/ua/jobseekers-preform/
# https//t.me/ukrpage_jobs)
# https//mischutka.ch/
# ...
# https//www.zvv.ch/zvv/de/abos-und-tickets
# https//t.me/zh_housing
# https//www.google.com/maps/place/Morillonstrasse+75,+3007+Bern
# https//www.google.com/maps/place/Morillonstrasse+75,+3007+Bern
# https//www.google.com/maps/place/Morillonstrasse+75,+3007+Bern
# https//t.me/zh_helps_UArefugee,
# https//t.me/zh_helps
# https//t.me/zh_helps_UArefugee
# https//www.allianceswisspass.ch/de/tarife-vorschriften/tarifmassnahmen
# https//www.allianceswisspass.ch/de/tarife-vorschriften/tarifmassnahmen
# https//www.sem.admin.ch/sem/en/home
# https//www.sem.admin.ch/sem/de/home
# https//t.me/zh_helps_ukraine
# https//www.stadt-zuerich.ch/content/aoz/de
# https//en.ors-group.org/
# https//regionalbuero-zuerich.heilsarmee.ch/
# http//www.bfm.admin.ch/content/bfm/de
# https//t.me/brain_drain_ru
# https//europa.eu/youth/solidarity/young-people
# https//t.me/zurich_hb_help/11348.
# https//t.me/zh_helps_UArefugee/39344
# https//t.me/zh_helps_UArefugee/52691
# https//t.me/zh_helps_UArefugee/39344
# https//t.me/zurich_hb_help/5796
# https//t.me/zh_helps
# https//rechtsberatungsstelle.ch/
# https//t.me/zh_helps_UArefugee/39344
# https//t.me/zh_back_ukraine/9423
# https//t.me/zh_back_ukraine
# https//t.me/zh_helps_UArefugee
# https//www.oebb.at/en/neuigkeiten/ukraine-hilfe
# https//t.me/zh_back_ukraine/9516
# https//t.me/zh_back_ukraine/9605
# https//www.allianceswisspass.ch/de/tarife-vorschriften/tarifmassnahmen
# https//t.me/LousanneUkraine
# https//t.me/zh_helps_UArefugee
# https//t.me/zh_helps/29062
# https//t.me/zh_helps_UArefugee
# https//t.me/zh_helps_UArefugee,
# https//t.me/zh_helps_UArefugee
# https//www.zh.ch/de/migration-integration/ukrainehilfe
# https//t.me/zh_helps_UArefugee/53570
# https//www.zav.ch/fuer-rechtssuchende/anwaltssuche.html
# https//t.me/zurich_hb_help/5796
# https//t.me/zh_helps_UArefugee/39344
# https//t.me/zh
# https//t.me/zh_helps_UArefugee/39344
# https//www.sem.admin.ch/sem/en/home
# https//t.me/railadventure
# https//t.me/zh_back_ukraine
# https//t.me/zh_helps_UArefugee
# https//t.me/zh_helps_UArefugee/39344
# https//t.me/zh_back_ukraine,
# https//t.me/pereviznikyCHUA
# https//t.me/LousanneUkraine
# https//www.ua-ru.eu/
# https//helpua.rubikus.de/

# %%
pd.Series(urlTelegramList).value_counts().to_csv("../data/telegram_queries/mostSharedLinksTelegramGroups.csv")

# %%
pd.Series(urlList).value_counts().to_csv("../data/results/value_counts_links_send.csv")

# %%
pd.Series(urlTelegramList).value_counts().to_csv("../data/value_counts_telegramchannels.csv")

# %% [markdown]
# # Bag of Words & TF-IDF

# %%
#define stopwords
from nltk.corpus import stopwords
stopWords = stopwords.words('english') 
for word in stopwords.words('german'):
    stopWords.append(stopwords)
for word in stopwords.words('russian'):
    stopWords.append(word)
ukrstopWords = ['а', 'аби', 'абиде', 'абиким', 'абикого', 'абиколи', 'абикому', 'абикуди', 'абихто', 'абичий', 'абичийого', 'абичийому', 'абичим', 'абичию', 'абичия', 'абичиє', 'абичиєму', 'абичиєю', 'абичиєї', 'абичиї', 'абичиїй', 'абичиїм', 'абичиїми', 'абичиїх', 'абичого', 'абичому', 'абищо', 'абияка', 'абияке', 'абиякий', 'абияким', 'абиякими', 'абияких', 'абиякого', 'абиякому', 'абиякою', 'абиякої', 'абияку', 'абиякі', 'абиякій', 'абиякім', 'або', 'абощо', 'авжеж', 'авось', 'ага', 'ад', 'адже', 'аж', 'ажень', 'аз', 'ай', 'але', 'ало', 'амінь', 'ант', 'ану', 'ані', 'аніде', 'аніж', 'анізащо', 'аніким', 'анікого', 'анікогісінько', 'аніколи', 'анікому', 'аніскільки', 'аніхто', 'анічим', 'анічого', 'анічогісінько', 'анічому', 'аніщо', 'аніяка', 'аніяке', 'аніякий', 'аніяким', 'аніякими', 'аніяких', 'аніякого', 'аніякому', 'аніякою', 'аніякої', 'аніяку', 'аніякі', 'аніякій', 'аніякім', 'аніякісенька', 'аніякісеньке', 'аніякісенький', 'аніякісеньким', 'аніякісенькими', 'аніякісеньких', 'аніякісенького', 'аніякісенькому', 'аніякісенькою', 'аніякісенької', 'аніякісеньку', 'аніякісенькі', 'аніякісенькій', 'аніякісенькім', 'аніякісінька', 'аніякісіньке', 'аніякісінький', 'аніякісіньким', 'аніякісінькими', 'аніякісіньких', 'аніякісінького', 'аніякісінькому', 'аніякісінькою', 'аніякісінької', 'аніякісіньку', 'аніякісінькі', 'аніякісінькій', 'аніякісінькім', 'ат', 'ато', 'атож', 'ау', 'ах', 'ач', 'ачей', 'аякже', 'б', 'ба', 'багато', 'багатьма', 'багатьом', 'багатьох', 'баз', 'бай', 'бат', 'бах', 'бац', 'баш', 'бе', 'беж', 'без', 'безперервно', 'бел', 'бер', 'би', 'бир', 'бич', 'близько', 'близько від', 'бо', 'бов', 'бод', 'бодай', 'боз', 'бош', 'був', 'буває', 'буде', 'будем', 'будемо', 'будете', 'будеш', 'буду', 'будуть', 
як', 'сяка', 'сяке', 'сякий', 'сяким', 'сякими', 'сяких', 'сякого', 'сякому', 'сякою', 'сякої', 'сяку', 'сякі', 'сякій', 'сякім', 'сям', 'сі', 'сім', 'сімнадцятий', 'сімнадцять', 'сіп', 'т', 'та', 'таж', 'так', 'така', 'таке', 'такенна', 'такенне', 'такенний', 'такенним', 'такенними', 'такенних', 'такенного', 'такенному', 'такенною', 'такенної', 'такенну', 'такенні', 'такенній', 'такеннім', 'таки', 'такий', 'таким', 'такими', 'таких', 'такого', 'також', 'такому', 'такою', 'такої', 'таку', 'такі', 'такій', 'такім', 'такісінька', 'такісіньке', 'такісінький', 'такісіньким', 'такісінькими', 'такісіньких', 'такісінького', 'такісінькому', 'такісінькою', 'такісінької', 'такісіньку', 'такісінькі', 'такісінькій', 'такісінькім', 'тал', 'там', 'тамки', 'тамта', 'тамте', 'тамтим', 'тамтими', 'тамтих', 'тамтого', 'тамтой', 'тамтому', 'тамтою', 'тамтої', 'тамту', 'тамті', 'тамтій', 'тамтім', 'тамтією', 'тамтієї', 'тар', 'тат', 'таш', 'тва', 'твого', 'твою', 'твоя', 'твоє', 'твоєму', 'твоєю', 'твоєї', 'твої', 'твоїй', 'твоїм', 'твоїми', 'твоїх', 'твій', 'те', 'тебе', 'тег', 'теж', 'тем', 'тепер', 'теперечки', 'тес', 'теф', 'теє', 'ти', 'тик', 'тил', 'тим', 'тими', 'тисяч', 'тих', 'то', 'тобою', 'тобто', 'тобі', 'того', 'тоді', 'тож', 'той', 'тол', 'тому', 'тому що', 'тот', 'тощо', 'тою', 'тої', 'тра', 'тре', 'треба', 'третій', 'три', 'тринадцятий', 'тринадцять', 'трохи', 'тс', 'тсс', 'ту', 'туди', 'тудою', 'туп', 'тут', 'тутеньки', 'тутечки', 'тутки', 'туф', 'туц', 'тю', 'тюг', 'тюп', 'тяг', 'тяж', 'тям', 'тяп', 'ті', 'тій', 'тільки', 'тім', 'тією', 'у', 'у бік', 'у вигляді', 'у випадку', 'у відповідності до', 'у відповідь на', 'у залежності від', "у зв'язку з", 'у міру', 'у напрямі до', 'у порівнянні з', 'у процесі', 'у результаті', 'у ролі', 'у силу', 'у сторону', 'у супроводі', 'у ході', 'ув', 'увесь', 'уві', 'угу', 'уже', 'узбіч', 'уздовж', 'укр', 'ум', 'унаслідок', 'униз', 'унизу', 'унт', 'уперед', 'уподовж', 'упоперек', 'упритиск до', 'упритул до', 'упродовж', 'упрост', 'ус', 'усе', 'усередині', 'услід', 'услід за', 'усупереч', 'усього', 'усьому', 'усю', 'усюди', 'уся', 'усяк', 'усяка', 'усяке', 'усякий', 'усяким', 'усякими', 'усяких', 'усякого', 'усякому', 'усякою', 'усякої', 'усяку', 'усякі', 'усякій', 'усякім', 'усі', 'усій', 'усіляка', 'усіляке', 'усілякий', 'усіляким', 'усілякими', 'усіляких', 'усілякого', 'усілякому', 'усілякою', 'усілякої', 'усіляку', 'усілякі', 'усілякій', 'усілякім', 'усім', 'усіма', 'усіх', 'усією', 'усієї', 'утім', 'ух', 'ф', "ф'ю", 'фа', 'фаг', 'фай', 'фат', 'фе', 'фед', 'фез', 'фес', 'фет', 'фзн', 'фоб', 'фот', 'фра', 'фру', 'фу', 'фук', 'фур', 'фус', 'фіш', 'х', 'ха', 'хаз', 'хай', 'хап', 'хат', 'хащ', 'хе', 'хет', 'хи', 'хиб', 'хм', 'хо', 'хов', 'хол', 'хон', 'хоп', 'хор', 'хотіти', 'хоч', 'хоча', 'хочеш', 'хро', 'хрю', 'хто', 'хтось', 'ху', 'хуз', 'хук', 'хух', 'хху', 'хіба', 'ц', 'це', 'цебто', 'цей', 'цеп', 'ци', 'цим', 'цими', 'цир', 'цих', 'цло', 'цоб', 'цок', 'цоп', 'цор', 'цс', 'цсс', 'цуг', 'цур', 'цуц', 'цього', 'цьому', 'цю', 'цюк', 'ця', 'цяв', 'цяп', 'ці', 'цід', 'цій', 'цім', 'ціною', 'цією', 'цієї', 'ч', 'чал', 'чар', 'час', 'часто', 'частіше', 'часу', 'чах', 'чей', 'чень', 'через', 'четвертий', 'чи', 'чий', 'чийого', 'чийогось', 'чийому', 'чийомусь', 'чийсь', 'чик', 'чим', 'чимось', 'чимсь', 'чир', 'численна', 'численне', 'численний', 'численним', 'численними', 'численних', 'численні', 'чию', 'чиюсь', 'чия', 'чиясь', 'чиє', 'чиєму', 'чиємусь', 'чиєсь', 'чиєю', 'чиєюсь', 'чиєї', 'чиєїсь', 'чиї', 'чиїй', 'чиїйсь', 'чиїм', 'чиїми', 'чиїмись', 'чиїмось', 'чиїмсь', 'чиїсь', 'чиїх', 'чиїхось', 'чиїхсь', 'чля', 'чого', 'чогось', 'чом', 'чому', 'чомусь', 'чон', 'чоп', 'чортзна', 'чос', 'чотири', 'чотирнадцятий', 'чотирнадцять', 'чу', 'чум', 'чур', 'чш', 'чім', 'чімось', 'чімсь', 'чіт', 'ш', 'ша', 'шаг', 'шал', 'шам', 'шво', 'шед', 'шен', 'шиз', 'шир', 'шляхом', 'шостий', 'шістнадцятий', 'шістнадцять', 'шість', 'щ', 'ще', 'щем', 'щеп', 'щип', 'щир', 'що', 'щоб', 'щоби', 'щодо', 'щойно', 'щоправда', 'щось', 'щі', 'ь', 'ю', 'юз', 'юн', 'юнь', 'юс', 'ют', 'юхт', 'я', 'яв', 'яд', 'яз', 'язь', 'як', 'яка', 'якась', 'якби', 'яке', 'якесь', 'який', 'якийсь', 'яким', 'якими', 'якимись', 'якимось', 'якимсь', 'яких', 'якихось', 'якихсь', 'якого', 'якогось', 'якому', 'якомусь', 'якось', 'якою', 'якоюсь', 'якої', 'якоїсь', 'якраз', 'яку', 'якусь', 'якщо', 'які', 'якій', 'якійсь', 'якім', 'якімсь', 'якісь', 'ял', 'ям', 'ян', 'янь', 'яо', 'яп', 'ярл', 'ясь', 'ять', 'є', 'єр', 'єси', 'і', 'ібн', 'ід', 'із', 'із-за', 'із-під', 'іззаду', 'ізм', 'ізсередини', 'ік', 'ікс', 'ікт', "ім'я", 'імовірно', 'інакша', 'інакше', 'інакший', 'інакшим', 'інакшими', 'інакших', 'інакшого', 'інакшому', 'інакшою', 'інакшої', 'інакшу', 'інакші', 'інакшій', 'інакшім', 'інколи', 'іноді', 'інша', 'інше', 'інший', 'іншим', 'іншими', 'інших', 'іншого', 'іншому', 'іншою', 'іншої', 'іншу', 'інші', 'іншій', 'іншім', 'інь', 'іч', 'іще', 'ї', 'їдь', 'їй', 'їм', 'їх', 'їхнього', 'їхньому', 'їхньою', 'їхньої', 'їхню', 'їхня', 'їхнє', 'їхні', 'їхній', 'їхнім', 'їхніми', 'їхніх', 'її', 'ґ']
# ukrainian stopwords as list below
for word in ukrstopWords:
    stopWords.append(word)

# %%
"https://t.me/campax_ukraine_help_switzerland".split('/')[-1]
# Out:
# 'campax_ukraine_help_switzerland'

# %%
from sklearn.feature_extraction.text import CountVectorizer
corpus = df.messageText.to_list()
# corpus = ['Text processing is necessary.', 'Text processing is necessary and important.', 'Text processing is easy.']
vectorizer = CountVectorizer(stop_words=stopWords)
bow = vectorizer.fit_transform(corpus)
# print(vectorizer.get_feature_names())
# dfBOW= pd.DataFrame(X.toarray(),columns=vectorizer.get_feature_names())
sum_words = bow.sum(axis=0) 
word_freq = [(word, sum_words[0, idx]) for word, idx in  vectorizer.vocabulary_.items()]
word_freq =sorted(word_freq, key = lambda x: x[1], reverse=True)

# %%
# TODO why are all tf idf values 0
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer(stop_words=stopWords)
vectorizer = TfidfVectorizer(stop_words=stopWords)#, max_df=0.75, min_df=0)
# vectorizer = TfidfVectorizer(sublinear_tf=True, min_df=5,ngram_range=(1, 2), stop_words=stopWords)
tfIdf = vectorizer.fit_transform(corpus)
dfTfIdf = pd.DataFrame(tfIdf[0].T.todense(), index=vectorizer.get_feature_names(), columns=["TF-IDF"])
dfTfIdf = dfTfIdf.sort_values('TF-IDF', ascending=False)
# print(X.toarray())
# Out:
# /Users/kiliansprenkamp/miniconda3/envs/telegram/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/kiliansprenkamp/Desktop/OneDrive - Universität Zürich UZH/migrantZurich/unsupervised-migrant-telegram-analysis/reports/analysis.ipynb Cell 19 in <cell line: 7>()
#       <a href='vscode-notebook-cell:/Users/kiliansprenkamp/Desktop/OneDrive%20-%20Universit%C3%A4t%20Z%C3%BCrich%20UZH/migrantZurich/unsupervised-migrant-telegram-analysis/reports/analysis.ipynb#X24sZmlsZQ%3D%3D?line=4'>5</a> # vectorizer = TfidfVectorizer(sublinear_tf=True, min_df=5,ngram_range=(1, 2), stop_words=stopWords)
#       <a href='vscode-notebook-cell:/Users/kiliansprenkamp/Desktop/OneDrive%20-%20Universit%C3%A4t%20Z%C3%BCrich%20UZH/migrantZurich/unsupervised-migrant-telegram-analysis/reports/analysis.ipynb#X24sZmlsZQ%3D%3D?line=5'>6</a> tfIdf = vectorizer.fit_transform(corpus)
# ----> <a href='vscode-notebook-cell:/Users/kiliansprenkamp/Desktop/OneDrive%20-%20Universit%C3%A4t%20Z%C3%BCrich%20UZH/migrantZurich/unsupervised-migrant-telegram-analysis/reports/analysis.ipynb#X24sZmlsZQ%3D%3D?line=6'>7</a> dfTfIdf = pd.DataFrame(tfIdf[0].todense(), index=vectorizer.get_feature_names(), columns=["TF-IDF"])
#       <a href='vscode-notebook-cell:/Users/kiliansprenkamp/Desktop/OneDrive%20-%20Universit%C3%A4t%20Z%C3%BCrich%20UZH/migrantZurich/unsupervised-migrant-telegram-analysis/reports/analysis.ipynb#X24sZmlsZQ%3D%3D?line=7'>8</a> dfTfIdf = dfTfIdf.sort_values('TF-IDF', ascending=False)
#
# File ~/miniconda3/envs/telegram/lib/python3.9/site-packages/pandas/core/frame.py:672, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     662         mgr = dict_to_mgr(
#     663             # error: Item "ndarray" of "Union[ndarray, Series, Index]" has no
#     664             # attribute "name"
#    (...)
#     669             typ=manager,
#     670         )
#     671     else:
# --> 672         mgr = ndarray_to_mgr(
#     673             data,
#     674             index,
#     675             columns,
#     676             dtype=dtype,
#     677             copy=copy,
#     678             typ=manager,
#     679         )
#     681 # For data is list-like, or Iterable (will consume into list)
#     682 elif is_list_like(data):
#
# File ~/miniconda3/envs/telegram/lib/python3.9/site-packages/pandas/core/internals/construction.py:324, in ndarray_to_mgr(values, index, columns, dtype, copy, typ)
#     319 # _prep_ndarray ensures that values.ndim == 2 at this point
#     320 index, columns = _get_axes(
#     321     values.shape[0], values.shape[1], index=index, columns=columns
#     322 )
# --> 324 _check_values_indices_shape_match(values, index, columns)
#     326 if typ == "array":
#     328     if issubclass(values.dtype.type, str):
#
# File ~/miniconda3/envs/telegram/lib/python3.9/site-packages/pandas/core/internals/construction.py:393, in _check_values_indices_shape_match(values, index, columns)
#     391 passed = values.shape
#     392 implied = (len(index), len(columns))
# --> 393 raise ValueError(f"Shape of passed values is {passed}, indices imply {implied}")
#
# ValueError: Shape of passed values is (1, 238755), indices imply (238755, 1)

# %%
dfTfIdf.to_csv('../data/results/tfidf.csv')

# %% [markdown]
# # Hugging Face

# %%
# rating 1-5 stars text classifier not trained for ukr or rus, but works fairly well
from transformers import AutoTokenizer, AutoModelForSequenceClassification

tokenizer = AutoTokenizer.from_pretrained("nlptown/bert-base-multilingual-uncased-sentiment")

model = AutoModelForSequenceClassification.from_pretrained("nlptown/bert-base-multilingual-uncased-sentiment")

# %%
def sentiment_classifier(model, message):
    inputs = tokenizer(message, return_tensors="pt")
    with torch.no_grad():
        logits = model(**inputs).logits
    return logits
# predicted_class_id = logits.argmax().item()
# model.config.id2label[predicted_class_id]

# %%
dfT = dfT[dfT["messageText"].str.len()<512]
dfT['sentiment'] = dfT.messageText.apply(lambda x: sentiment_classifier(model, x))
dfT['star_rating'] = dfT.sentiment.apply(lambda x: model.config.id2label[x.argmax().item()][0])
# dfT.to_csv("../data/sentiment.csv", index=False)

# %%
dfT = pd.read_csv("../data/results/sentiment.csv")

# %%
mean_ratings_dict = {}
for i in df_stakeholder.type_code:
    mean_ratings_dict[i] =dfT[dfT['type_code'].str.contains(i, case=False)].star_rating.mean()

# %%
mean_ratings_dict
# Out:
# {'NP_ESSEN': 4.09375,
#  'PC_Hotellerie': nan,
#  'V_Helper': 3.012558869701727,
#  'S_Social': 2.257425742574257,
#  'S_Police': 2.2264150943396226,
#  'S_Education': 4.0,
#  'V_Host': 2.442528735632184,
#  'RO_AOZ': 2.16600790513834,
#  'NP_Shelters': 2.7476635514018692,
#  'E_German': 3.2303030303030305,
#  'NP_Campax': 2.566666666666667,
#  'OP_Job': 3.0,
#  'R_Refugees': nan,
#  'NP_Donation': 2.8127659574468087,
#  'PC_Shops': 2.76875,
#  'OP_Accommodation': 4.0,
#  'S_Communes': 2.413294797687861,
#  'PC_Hotels': 2.5233644859813085,
#  'S_Labor': 2.6296296296296298,
#  'NP_SGG': 2.3333333333333335,
#  'NP_SFL': 1.5,
#  'S_Kanzlei': 2.617021276595745,
#  'E_Kindergarten': 2.7555555555555555,
#  'OP_MoneyCollect': 3.2905405405405403,
#  'S_Veterinary': 3.015748031496063,
#  'S_Health': nan,
#  'S_Migration': 2.1272727272727274,
#  'E_Schools': 2.844,
#  'OP_Info': 4.0,
#  'NP_WKP': nan,
#  'RO_BAZ': 2.2661870503597124}

# %%
# misinformation, factual, other classifier Not very useful for us
import torch
from transformers import AutoTokenizer, AutoModelForSequenceClassification

tokenizer = AutoTokenizer.from_pretrained("saattrupdan/verdict-classifier")

model = AutoModelForSequenceClassification.from_pretrained("saattrupdan/verdict-classifier")

# %%
# transformer for slavic to english
df = pd.read_csv("../models/BERTopic_50Char10Classes/pred_on_whole_data.csv")

from transformers import MarianTokenizer, MarianMTModel
import torch

# src = "uk"  # source language
# trg = "en"  # target language

model_name = f"Helsinki-NLP/opus-mt-tc-big-zle-en"
model = MarianMTModel.from_pretrained(model_name)
tokenizer = MarianTokenizer.from_pretrained(model_name)
# tokenizer.to("mps")

# model.to(torch.device("mps"))
sample_text =  df.messageText[0]
batch = tokenizer([sample_text], return_tensors="pt")

generated_ids = model.generate(**batch)
tokenizer.batch_decode(generated_ids, skip_special_tokens=True)[0]
# Out:
# 'I’ve been here 15 years, so I’m surprised at the lack of seemingly logical questions.'

# %%
df = df[df["messageText"].str.len()<512]
df = df[df.cluster != -1 ]

# %%
df.shape
# Out:
# (27984, 6)

# %%
from tqdm import tqdm
tqdm.pandas()
df['messageTextEnglish'] = df['messageText'].progress_apply(lambda x: tokenizer.batch_decode(model.generate(**tokenizer([x], return_tensors="pt")), skip_special_tokens=True)[0])
# df_classifier.to_csv("../data/results/testingClassifier.csv", index=False)
# Out:
#   0%|          | 0/27984 [00:00<?, ?it/s]
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
#   6%|▌         | 1679/27984 [1:10:42<18:27:43,  2.53s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/kiliansprenkamp/Desktop/OneDrive - Universität Zürich UZH/migrantZurich/unsupervised-migrant-telegram-analysis/reports/analysis.ipynb Cell 34 in <cell line: 3>()
#       <a href='vscode-notebook-cell:/Users/kiliansprenkamp/Desktop/OneDrive%20-%20Universit%C3%A4t%20Z%C3%BCrich%20UZH/migrantZurich/unsupervised-migrant-telegram-analysis/reports/analysis.ipynb#X44sZmlsZQ%3D%3D?line=0'>1</a> from tqdm import tqdm
#       <a href='vscode-notebook-cell:/Users/kiliansprenkamp/Desktop/OneDrive%20-%20Universit%C3%A4t%20Z%C3%BCrich%20UZH/migrantZurich/unsupervised-migrant-telegram-analysis/reports/analysis.ipynb#X44sZmlsZQ%3D%3D?line=1'>2</a> tqdm.pandas()
# ----> <a href='vscode-notebook-cell:/Users/kiliansprenkamp/Desktop/OneDrive%20-%20Universit%C3%A4t%20Z%C3%BCrich%20UZH/migrantZurich/unsupervised-migrant-telegram-analysis/reports/analysis.ipynb#X44sZmlsZQ%3D%3D?line=2'>3</a> df['messageTextEnglish'] = df['messageText'].progress_apply(lambda x: tokenizer.batch_decode(model.generate(**tokenizer([x], return_tensors="pt")), skip_special_tokens=True)[0])
#
# File ~/miniconda3/envs/telegram/lib/python3.9/site-packages/tqdm/std.py:814, in tqdm.pandas.<locals>.inner_generator.<locals>.inner(df, func, *args, **kwargs)
#     811 # Apply the provided function (in **kwargs)
#     812 # on the df using our wrapper (which provides bar updating)
#     813 try:
# --> 814     return getattr(df, df_function)(wrapper, **kwargs)
#     815 finally:
#     816     t.close()
#
# File ~/miniconda3/envs/telegram/lib/python3.9/site-packages/pandas/core/series.py:4357, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4247 def apply(
#    4248     self,
#    4249     func: AggFuncType,
#    (...)
#    4252     **kwargs,
#    4253 ) -> FrameOrSeriesUnion:
#    4254     """
#    4255     Invoke function on values of Series.
#    4256
#    (...)
#    4355     dtype: float64
#    4356     """
# -> 4357     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File ~/miniconda3/envs/telegram/lib/python3.9/site-packages/pandas/core/apply.py:1043, in SeriesApply.apply(self)
#    1039 if isinstance(self.f, str):
#    1040     # if we are a string, try to dispatch
#    1041     return self.apply_str()
# -> 1043 return self.apply_standard()
#
# File ~/miniconda3/envs/telegram/lib/python3.9/site-packages/pandas/core/apply.py:1098, in SeriesApply.apply_standard(self)
#    1092         values = obj.astype(object)._values
#    1093         # error: Argument 2 to "map_infer" has incompatible type
#    1094         # "Union[Callable[..., Any], str, List[Union[Callable[..., Any], str]],
#    1095         # Dict[Hashable, Union[Union[Callable[..., Any], str],
#    1096         # List[Union[Callable[..., Any], str]]]]]"; expected
#    1097         # "Callable[[Any], Any]"
# -> 1098         mapped = lib.map_infer(
#    1099             values,
#    1100             f,  # type: ignore[arg-type]
#    1101             convert=self.convert_dtype,
#    1102         )
#    1104 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1105     # GH 25959 use pd.array instead of tolist
#    1106     # so extension arrays can be used
#    1107     return obj._constructor_expanddim(pd_array(mapped), index=obj.index)
#
# File ~/miniconda3/envs/telegram/lib/python3.9/site-packages/pandas/_libs/lib.pyx:2859, in pandas._libs.lib.map_infer()
#
# File ~/miniconda3/envs/telegram/lib/python3.9/site-packages/tqdm/std.py:809, in tqdm.pandas.<locals>.inner_generator.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     803 def wrapper(*args, **kwargs):
#     804     # update tbar correctly
#     805     # it seems `pandas apply` calls `func` twice
#     806     # on the first column/row to decide whether it can
#     807     # take a fast or slow code path; so stop when t.total==t.n
#     808     t.update(n=1 if not t.total or t.n < t.total else 0)
# --> 809     return func(*args, **kwargs)
#
# /Users/kiliansprenkamp/Desktop/OneDrive - Universität Zürich UZH/migrantZurich/unsupervised-migrant-telegram-analysis/reports/analysis.ipynb Cell 34 in <lambda>(x)
#       <a href='vscode-notebook-cell:/Users/kiliansprenkamp/Desktop/OneDrive%20-%20Universit%C3%A4t%20Z%C3%BCrich%20UZH/migrantZurich/unsupervised-migrant-telegram-analysis/reports/analysis.ipynb#X44sZmlsZQ%3D%3D?line=0'>1</a> from tqdm import tqdm
#       <a href='vscode-notebook-cell:/Users/kiliansprenkamp/Desktop/OneDrive%20-%20Universit%C3%A4t%20Z%C3%BCrich%20UZH/migrantZurich/unsupervised-migrant-telegram-analysis/reports/analysis.ipynb#X44sZmlsZQ%3D%3D?line=1'>2</a> tqdm.pandas()
# ----> <a href='vscode-notebook-cell:/Users/kiliansprenkamp/Desktop/OneDrive%20-%20Universit%C3%A4t%20Z%C3%BCrich%20UZH/migrantZurich/unsupervised-migrant-telegram-analysis/reports/analysis.ipynb#X44sZmlsZQ%3D%3D?line=2'>3</a> df['messageTextEnglish'] = df['messageText'].progress_apply(lambda x: tokenizer.batch_decode(model.generate(**tokenizer([x], return_tensors="pt")), skip_special_tokens=True)[0])
#
# File ~/miniconda3/envs/telegram/lib/python3.9/site-packages/torch/autograd/grad_mode.py:28, in _DecoratorContextManager.__call__.<locals>.decorate_context(*args, **kwargs)
#      25 @functools.wraps(func)
#      26 def decorate_context(*args, **kwargs):
#      27     with self.__class__():
# ---> 28         return func(*args, **kwargs)
#
# File ~/miniconda3/envs/telegram/lib/python3.9/site-packages/transformers/generation_utils.py:1354, in GenerationMixin.generate(self, inputs, max_length, min_length, do_sample, early_stopping, num_beams, temperature, top_k, top_p, typical_p, repetition_penalty, bad_words_ids, force_words_ids, bos_token_id, pad_token_id, eos_token_id, length_penalty, no_repeat_ngram_size, encoder_no_repeat_ngram_size, num_return_sequences, max_time, max_new_tokens, decoder_start_token_id, use_cache, num_beam_groups, diversity_penalty, prefix_allowed_tokens_fn, logits_processor, renormalize_logits, stopping_criteria, constraints, output_attentions, output_hidden_states, output_scores, return_dict_in_generate, forced_bos_token_id, forced_eos_token_id, remove_invalid_values, synced_gpus, exponential_decay_length_penalty, **model_kwargs)
#    1350     input_ids, model_kwargs = self._expand_inputs_for_generation(
#    1351         input_ids, expand_size=num_beams, is_encoder_decoder=self.config.is_encoder_decoder, **model_kwargs
#    1352     )
#    1353     # 12. run beam search
# -> 1354     return self.beam_search(
#    1355         input_ids,
#    1356         beam_scorer,
#    1357         logits_processor=logits_processor,
#    1358         stopping_criteria=stopping_criteria,
#    1359         pad_token_id=pad_token_id,
#    1360         eos_token_id=eos_token_id,
#    1361         output_scores=output_scores,
#    1362         return_dict_in_generate=return_dict_in_generate,
#    1363         synced_gpus=synced_gpus,
#    1364         **model_kwargs,
#    1365     )
#    1367 elif is_beam_sample_gen_mode:
#    1368     # 10. prepare logits warper
#    1369     logits_warper = self._get_logits_warper(
#    1370         top_k=top_k,
#    1371         top_p=top_p,
#    (...)
#    1375         renormalize_logits=renormalize_logits,
#    1376     )
#
# File ~/miniconda3/envs/telegram/lib/python3.9/site-packages/transformers/generation_utils.py:2277, in GenerationMixin.beam_search(self, input_ids, beam_scorer, logits_processor, stopping_criteria, max_length, pad_token_id, eos_token_id, output_attentions, output_hidden_states, output_scores, return_dict_in_generate, synced_gpus, **model_kwargs)
#    2273 model_kwargs = self._update_model_kwargs_for_generation(
#    2274     outputs, model_kwargs, is_encoder_decoder=self.config.is_encoder_decoder
#    2275 )
#    2276 if model_kwargs["past"] is not None:
# -> 2277     model_kwargs["past"] = self._reorder_cache(model_kwargs["past"], beam_idx)
#    2279 if return_dict_in_generate and output_scores:
#    2280     beam_indices = tuple((beam_indices[beam_idx[i]] + (beam_idx[i],) for i in range(len(beam_indices))))
#
# File ~/miniconda3/envs/telegram/lib/python3.9/site-packages/transformers/models/marian/modeling_marian.py:1519, in MarianMTModel._reorder_cache(past, beam_idx)
#    1515 reordered_past = ()
#    1516 for layer_past in past:
#    1517     # cached cross_attention states don't have to be reordered -> they are always the same
#    1518     reordered_past += (
# -> 1519         tuple(past_state.index_select(0, beam_idx) for past_state in layer_past[:2]) + layer_past[2:],
#    1520     )
#    1521 return reordered_past
#
# File ~/miniconda3/envs/telegram/lib/python3.9/site-packages/transformers/models/marian/modeling_marian.py:1519, in <genexpr>(.0)
#    1515 reordered_past = ()
#    1516 for layer_past in past:
#    1517     # cached cross_attention states don't have to be reordered -> they are always the same
#    1518     reordered_past += (
# -> 1519         tuple(past_state.index_select(0, beam_idx) for past_state in layer_past[:2]) + layer_past[2:],
#    1520     )
#    1521 return reordered_past
#
# KeyboardInterrupt:

# %%
df_classifier = pd.read_csv("../data/results/testingClassifierTelegram.csv")
df_classifier.messageTextEnglish
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /Users/kiliansprenkamp/Library/CloudStorage/OneDrive-UniversitätZürichUZH/migrantZurich/refugeeAnalysis/reports/analysis.ipynb Cell 62 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/kiliansprenkamp/Library/CloudStorage/OneDrive-Universita%CC%88tZu%CC%88richUZH/migrantZurich/refugeeAnalysis/reports/analysis.ipynb#Y115sZmlsZQ%3D%3D?line=0'>1</a> df_classifier = pd.read_csv("../data/results/testingClassifierTelegram.csv")
#       <a href='vscode-notebook-cell:/Users/kiliansprenkamp/Library/CloudStorage/OneDrive-Universita%CC%88tZu%CC%88richUZH/migrantZurich/refugeeAnalysis/reports/analysis.ipynb#Y115sZmlsZQ%3D%3D?line=1'>2</a> df_classifier.messageTextEnglish
#
# File ~/miniconda3/envs/telegram/lib/python3.9/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~/miniconda3/envs/telegram/lib/python3.9/site-packages/pandas/io/parsers/readers.py:680, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     665 kwds_defaults = _refine_defaults_read(
#     666     dialect,
#     667     delimiter,
#    (...)
#     676     defaults={"delimiter": ","},
#     677 )
#     678 kwds.update(kwds_defaults)
# --> 680 return _read(filepath_or_buffer, kwds)
#
# File ~/miniconda3/envs/telegram/lib/python3.9/site-packages/pandas/io/parsers/readers.py:575, in _read(filepath_or_buffer, kwds)
#     572 _validate_names(kwds.get("names", None))
#     574 # Create the parser.
# --> 575 parser = TextFileReader(filepath_or_buffer, **kwds)
#     577 if chunksize or iterator:
#     578     return parser
#
# File ~/miniconda3/envs/telegram/lib/python3.9/site-packages/pandas/io/parsers/readers.py:933, in TextFileReader.__init__(self, f, engine, **kwds)
#     930     self.options["has_index_names"] = kwds["has_index_names"]
#     932 self.handles: IOHandles | None = None
# --> 933 self._engine = self._make_engine(f, self.engine)
#
# File ~/miniconda3/envs/telegram/lib/python3.9/site-packages/pandas/io/parsers/readers.py:1217, in TextFileReader._make_engine(self, f, engine)
#    1213     mode = "rb"
#    1214 # error: No overload variant of "get_handle" matches argument types
#    1215 # "Union[str, PathLike[str], ReadCsvBuffer[bytes], ReadCsvBuffer[str]]"
#    1216 # , "str", "bool", "Any", "Any", "Any", "Any", "Any"
# -> 1217 self.handles = get_handle(  # type: ignore[call-overload]
#    1218     f,
#    1219     mode,
#    1220     encoding=self.options.get("encoding", None),
#    1221     compression=self.options.get("compression", None),
#    1222     memory_map=self.options.get("memory_map", False),
#    1223     is_text=is_text,
#    1224     errors=self.options.get("encoding_errors", "strict"),
#    1225     storage_options=self.options.get("storage_options", None),
#    1226 )
#    1227 assert self.handles is not None
#    1228 f = self.handles.handle
#
# File ~/miniconda3/envs/telegram/lib/python3.9/site-packages/pandas/io/common.py:789, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     784 elif isinstance(handle, str):
#     785     # Check whether the filename is to be opened in binary mode.
#     786     # Binary mode does not support 'encoding' and 'newline'.
#     787     if ioargs.encoding and "b" not in ioargs.mode:
#     788         # Encoding
# --> 789         handle = open(
#     790             handle,
#     791             ioargs.mode,
#     792             encoding=ioargs.encoding,
#     793             errors=errors,
#     794             newline="",
#     795         )
#     796     else:
#     797         # Binary mode
#     798         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../data/results/testingClassifierTelegram.csv'

# %%
df_classifier.messageTextEnglish.to_csv("../data/results/testingClassifier.csv", index=None, header=None)

# %%
dfZ.to_csv(f"opus-mt-{src}-{trg}Translated.csv", index=None)

# %%
from transformers import AutoTokenizer, AutoModelForTokenClassification
from transformers import pipeline

tokenizer = AutoTokenizer.from_pretrained("dslim/bert-base-NER")
model = AutoModelForTokenClassification.from_pretrained("dslim/bert-base-NER")

nlp = pipeline("ner", model=model, tokenizer=tokenizer)
example = "My name is Wolfgang and I live in Berlin"

ner_results = nlp(example)
print(ner_results)
# Out:
# [{'entity': 'B-PER', 'score': 0.9990139, 'index': 4, 'word': 'Wolfgang', 'start': 11, 'end': 19}, {'entity': 'B-LOC', 'score': 0.999645, 'index': 9, 'word': 'Berlin', 'start': 34, 'end': 40}]

# %%
df = pd.read_csv("data/opus-mt-uk-enTranslatedNer.csv")

# %%
dfNlp = pd.DataFrame(nlp(dfZ.to_string(columns=["messageTextEnglish"], index=False).replace('\n',' ')))

# %%
dfZ['NER'] = dfZ['messageTextEnglish'].apply(lambda x: nlp(x))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/miniforge3/envs/telegram/lib/python3.9/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~/miniforge3/envs/telegram/lib/python3.9/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/miniforge3/envs/telegram/lib/python3.9/site-packages/pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'messageTextEnglish'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /Users/kiliansprenkamp/Library/CloudStorage/OneDrive-UniversitätZürichUZH/migrantZurich/refugeeAnalysis/reports/analysis.ipynb Cell 68 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/kiliansprenkamp/Library/CloudStorage/OneDrive-Universita%CC%88tZu%CC%88richUZH/migrantZurich/refugeeAnalysis/reports/analysis.ipynb#ch0000052?line=0'>1</a> dfZ['NER'] = dfZ['messageTextEnglish'].apply(lambda x: nlp(x))
#
# File ~/miniforge3/envs/telegram/lib/python3.9/site-packages/pandas/core/frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File ~/miniforge3/envs/telegram/lib/python3.9/site-packages/pandas/core/indexes/base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: 'messageTextEnglish'

# %%
df = pd.read_json('../data/TREC-IS/TRECIS-2018-2020B.json')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/kiliansprenkamp/Library/CloudStorage/OneDrive-UniversitätZürichUZH/migrantZurich/refugeeAnalysis/reports/analysis.ipynb Cell 68 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/kiliansprenkamp/Library/CloudStorage/OneDrive-Universita%CC%88tZu%CC%88richUZH/migrantZurich/refugeeAnalysis/reports/analysis.ipynb#ch0000088?line=0'>1</a> df = pd.read_json('../data/TREC-IS/TRECIS-2018-2020B.json')
#
# File ~/miniforge3/envs/telegram/lib/python3.9/site-packages/pandas/util/_decorators.py:207, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     205     else:
#     206         kwargs[new_arg_name] = new_arg_value
# --> 207 return func(*args, **kwargs)
#
# File ~/miniforge3/envs/telegram/lib/python3.9/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~/miniforge3/envs/telegram/lib/python3.9/site-packages/pandas/io/json/_json.py:612, in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit, encoding, encoding_errors, lines, chunksize, compression, nrows, storage_options)
#     609     return json_reader
#     611 with json_reader:
# --> 612     return json_reader.read()
#
# File ~/miniforge3/envs/telegram/lib/python3.9/site-packages/pandas/io/json/_json.py:746, in JsonReader.read(self)
#     744         obj = self._get_object_parser(self._combine_lines(data_lines))
#     745 else:
# --> 746     obj = self._get_object_parser(self.data)
#     747 self.close()
#     748 return obj
#
# File ~/miniforge3/envs/telegram/lib/python3.9/site-packages/pandas/io/json/_json.py:768, in JsonReader._get_object_parser(self, json)
#     766 obj = None
#     767 if typ == "frame":
# --> 768     obj = FrameParser(json, **kwargs).parse()
#     770 if typ == "series" or obj is None:
#     771     if not isinstance(dtype, bool):
#
# File ~/miniforge3/envs/telegram/lib/python3.9/site-packages/pandas/io/json/_json.py:880, in Parser.parse(self)
#     878     self._parse_numpy()
#     879 else:
# --> 880     self._parse_no_numpy()
#     882 if self.obj is None:
#     883     return None
#
# File ~/miniforge3/envs/telegram/lib/python3.9/site-packages/pandas/io/json/_json.py:1132, in FrameParser._parse_no_numpy(self)
#    1129 orient = self.orient
#    1131 if orient == "columns":
# -> 1132     self.obj = DataFrame(
#    1133         loads(json, precise_float=self.precise_float), dtype=None
#    1134     )
#    1135 elif orient == "split":
#    1136     decoded = {
#    1137         str(k): v
#    1138         for k, v in loads(json, precise_float=self.precise_float).items()
#    1139     }
#
# File ~/miniforge3/envs/telegram/lib/python3.9/site-packages/pandas/core/frame.py:636, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     630     mgr = self._init_mgr(
#     631         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     632     )
#     634 elif isinstance(data, dict):
#     635     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 636     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     637 elif isinstance(data, ma.MaskedArray):
#     638     import numpy.ma.mrecords as mrecords
#
# File ~/miniforge3/envs/telegram/lib/python3.9/site-packages/pandas/core/internals/construction.py:502, in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     494     arrays = [
#     495         x
#     496         if not hasattr(x, "dtype") or not isinstance(x.dtype, ExtensionDtype)
#     497         else x.copy()
#     498         for x in arrays
#     499     ]
#     500     # TODO: can we get rid of the dt64tz special case above?
# --> 502 return arrays_to_mgr(arrays, columns, index, dtype=dtype, typ=typ, consolidate=copy)
#
# File ~/miniforge3/envs/telegram/lib/python3.9/site-packages/pandas/core/internals/construction.py:120, in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, typ, consolidate)
#     117 if verify_integrity:
#     118     # figure out the index, if necessary
#     119     if index is None:
# --> 120         index = _extract_index(arrays)
#     121     else:
#     122         index = ensure_index(index)
#
# File ~/miniforge3/envs/telegram/lib/python3.9/site-packages/pandas/core/internals/construction.py:677, in _extract_index(data)
#     674     raise ValueError("All arrays must be of the same length")
#     676 if have_dicts:
# --> 677     raise ValueError(
#     678         "Mixing dicts with non-Series may lead to ambiguous ordering."
#     679     )
#     681 if have_series:
#     682     assert index is not None  # for mypy
#
# ValueError: Mixing dicts with non-Series may lead to ambiguous ordering.
